# %%
import pandas as pd
import numpy as np

src='data/originality.csv'
# names=['index', 'id', 'cit_received']
# usecols=['id', 'cit_received']
# dtype={'id':object, 'cit_received':'int64'}
# cols=['patent_id','citation_id', 'cit_delay']

df = pd.read_csv(src, chunksize=1000)
# df = pd.read_csv(src, usecols=usecols, names=names, chunksize=1000, dtype=dtype, index_col='id')
# df=pd.read_csv(src, usecols=[0, 1, 3], dtype={0:object}, index_col=0, chunksize=1000)

# %%
df.get_chunk().dtypes
# Out:
# patent_id           int64
# df_squared        float64
# total_citation      int64
# herfindal         float64
# originality       float64
# dtype: object

# %%
df.get_chunk()
# Out:
#      patent_id  df_squared  total_citation  herfindal  originality
# 0      4004367         1.0               1        1.0          0.0
# 1      4004409         1.0               1        1.0          0.0
# 2      4004415         1.0               1        1.0          0.0
# 3      4004452         1.0               1        1.0          0.0
# 4      4004487         1.0               1        1.0          0.0
# 5      4004500         1.0               1        1.0          0.0
# 6      4004521         1.0               1        1.0          0.0
# 7      4004528         1.0               1        1.0          0.0
# 8      4004533         1.0               1        1.0          0.0
# 9      4004534         1.0               1        1.0          0.0
# 10     4004541         1.0               1        1.0          0.0
# 11     4004562         1.0               1        1.0          0.0
# 12     4004564         1.0               1        1.0          0.0
# 13     4004571         1.0               1        1.0          0.0
# 14     4004572         1.0               1        1.0          0.0
# 15     4004615         1.0               1        1.0          0.0
# 16     4004636         1.0               1        1.0          0.0
# 17     4004681         1.0               1        1.0          0.0
# 18     4004704         1.0               1        1.0          0.0
# 19     4004705         1.0               1        1.0          0.0
# 20     4004709         1.0               1        1.0          0.0
# 21     4004724         1.0               1        1.0          0.0
# 22     4004736         1.0               1        1.0          0.0
# 23     4004742         1.0               1        1.0          0.0
# 24     4004757         1.0               1        1.0          0.0
# 25     4004847         1.0               1        1.0          0.0
# 26     4004848         1.0               1        1.0          0.0
# 27     4004852         1.0               1        1.0          0.0
# 28     4004859         1.0               1        1.0          0.0
# 29     4004860         1.0               1        1.0          0.0
# ..         ...         ...             ...        ...          ...
# 970    4016383         1.0               1        1.0          0.0
# 971    4016389         1.0               1        1.0          0.0
# 972    4016408         1.0               1        1.0          0.0
# 973    4016426         1.0               1        1.0          0.0
# 974    4016430         1.0               1        1.0          0.0
# 975    4016434         1.0               1        1.0          0.0
# 976    4016453         1.0               1        1.0          0.0
# 977    4016461         2.0               4        0.5          0.5
# 978    4016478         1.0               1        1.0          0.0
# 979    4016481         1.0               1        1.0          0.0
# 980    4016498         1.0               1        1.0          0.0
# 981    4016500         1.0               1        1.0          0.0
# 982    4016502         1.0               1        1.0          0.0
# 983    4016516         1.0               1        1.0          0.0
# 984    4016517         1.0               1        1.0          0.0
# 985    4016522         1.0               1        1.0          0.0
# 986    4016523         1.0               1        1.0          0.0
# 987    4016532         1.0               1        1.0          0.0
# 988    4016537         1.0               1        1.0          0.0
# 989    4016545         1.0               1        1.0          0.0
# 990    4016549         1.0               1        1.0          0.0
# 991    4016551         1.0               1        1.0          0.0
# 992    4016554         1.0               1        1.0          0.0
# 993    4016565         2.0               4        0.5          0.5
# 994    4016566         1.0               1        1.0          0.0
# 995    4016575         1.0               1        1.0          0.0
# 996    4016578         1.0               1        1.0          0.0
# 997    4016596         1.0               1        1.0          0.0
# 998    4016599         1.0               1        1.0          0.0
# 999    4016624         9.0               9        1.0          0.0
#
# [1000 rows x 5 columns]

# %%
df.get_chunk().applymap(np.isreal)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/parser.pyx in pandas.parser.TextReader._convert_tokens (pandas/parser.c:12580)()
#
# TypeError: Cannot cast array from dtype('O') to dtype('int64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-0b8090a5248d> in <module>()
# ----> 1 df.get_chunk().applymap(np.isreal)
#
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#     834         if size is None:
#     835             size = self.chunksize
# --> 836         return self.read(nrows=size)
#     837
#     838
#
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/pandas/io/parsers.py in read(self, nrows)
#     813                 raise ValueError('skip_footer not supported for iteration')
#     814
# --> 815         ret = self._engine.read(nrows)
#     816
#     817         if self.options.get('as_recarray'):
#
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1312     def read(self, nrows=None):
#    1313         try:
# -> 1314             data = self._reader.read(nrows)
#    1315         except StopIteration:
#    1316             if self._first_chunk:
#
# pandas/parser.pyx in pandas.parser.TextReader.read (pandas/parser.c:8748)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_low_memory (pandas/parser.c:9208)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_rows (pandas/parser.c:10022)()
#
# pandas/parser.pyx in pandas.parser.TextReader._convert_column_data (pandas/parser.c:11397)()
#
# pandas/parser.pyx in pandas.parser.TextReader._convert_tokens (pandas/parser.c:12656)()
#
# ValueError: invalid literal for int() with base 10: 'cit_received'

# %%
df2=[]

# %%
for chunk in df:
    chunk[chunk.cit_received.isstring()]
#     chunk.isnumeric()
#     df2.append(chunk[not chunk['cit_received'].apply(lambda x: x.isnumeric())])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-a4e1a49374ff> in <module>()
#       1 for chunk in df:
# ----> 2     chunk[chunk.cit_received.isstring()]
#       3 #     chunk.isnumeric()
#       4 #     df2.append(chunk[not chunk['cit_received'].apply(lambda x: x.isnumeric())])
#
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'isstring'

# %% [raw]
# df2.info()

# %%
df.sample(n=10)

# %%
df.rename(columns={'Unnamed: 0': 'citation_id'}, inplace=True)

df['citation_id']=df['citation_id'].astype(object)

# %%
df.dtypes

# %%
df.drop(['patent_id', 'Unnamed: 0.1', 'sequence', 'patent_id_raw'], inplace=True, axis=1)

# %%
df.columns({'Unnamed: 0':'citation_id'})

# %%
df.set_index('Unnamed: 0')

# %%
df['cit_delay']=pd.to_timedelta(df['cit_delay']).dt.components.days/365

# %%
back_delay=df.groupby('citation_id').cit_delay.agg(['mean', 'count'])
back_delay.rename(columns={'count': 'back_citation', 'mean':'mean_back_delay'}, inplace=True)
back_delay.head()

# %%
df.get_chunk().dtypes

# %%
names=['citation_id', 'back_citation', 'parent_back_citation', 'forw_citation']
df = pd.read_csv(src, names=names, chunksize=1000)

# %%
df.get_chunk().set_index('citation_id', inplace=True)

# %%
df=df.get_chunk()

# %%
df.set_index('citation_id', inplace=True)

# %%
df

# %%
df.get_chunk().astype(int)
