# %%
# February 11st, 2020
# Script to draw Originality and generality from different Classification systems

# %%
import pandas as pd
import numpy as np
# import itertools
# import seaborn as sns
# import networkx as nx
import csv
# from graphviz import Digraph
# import igraph
# import matplotlib.pyplot as plt
# import datetime


# import sys
# sys.path.append('/home/rkogeyam/scripts/')
# sys.path.append('scripts/')

# from determinants_scripts import classes, dtypes
import gzip

# %%
file=gzip.open('data/internal_external_cit.csv.gz', 'r')
#eigen='data/eigen333.csv'
#df=pd.read_csv(file, chunksize=100, engine='c', lineterminator='\n')

df=pd.read_csv(file, chunksize=1000)


# usecols=['patent_id', 'citation_id']
# df_cit=pd.read_csv(file, usecols=usecols, index_col='patent_id', chunksize=1000)

# df_asg=pd.read_csv(asg, sep='\t', chunksize=10000)

# df_cit=pd.read_csv(cit, usecols=usecols, chunksize=10000)
# 
# df=pd.read_csv(src, dtype=dtypes, usecols=usecols, parse_dates=['date'], index_col='id', chunksize=10000)
# df = pd.read_csv(src, chunksize=1000, usecols=usecols, dtypes=dtypes, parse_dates=['date'])

# df = pd.read_csv(src, chunksize=1000,  parse_dates=['date'], error_bad_lines=False)
# df = pd.read_csv(src, usecols=usecols, names=names, chunksize=1000, dtype=dtype, index_col='id')
# df=pd.read_csv(src, usecols=[0, 1, 3], dtype={0:object}, index_col=0, chunksize=1000)

# %%
# %matplotlib inline

# %%
df.get_chunk().columns
# Out:
# Index(['uuid', 'self_cit'], dtype='object')

# %%
df.get_chunk()
# Out:
#                           uuid  self_cit
# 0    pog788a2pdnfeibl9ltuliuhz         0
# 1    l6ryt3fu84t1niezl0he6699j         0
# 2    zspgqwt5pes9acu9o8gjtrosj         0
# 3    55n8vluqp5lizoxraljnz3yls         0
# 4    lphku6b2u23d1bzgdifni6shp         0
# 5    mpb0r0p2sa2uqnffsanybyvdd         0
# 6    e4tv7vhp0dsk01c927ie7hd2m         0
# 7    05fpng1gfxima28dy0ly5jf4x         0
# 8    njpuljsg5ico4h29duddl8siz         0
# 9    r8p0xwrbufsk33xilb47hjt71         0
# 10   f34q4g2s45szzwdjwsmq3emq8         0
# 11   g3xftfg4s2hqnar03930qqxom         0
# 12   fx499pa1thl3mjpqx21wze4nq         0
# 13   6mac9vrtrcwhsa94fmohu9mtt         0
# 14   fdba5tydm5huhhnxpsyfo0x76         0
# 15   tnh7s38t97aj7aegbtuiqca8t         0
# 16   3zd05qlsp33ciwwj1900g5x0e         0
# 17   1al25hbxmu8hsobg41otknja6         0
# 18   gu69b02p14dg9sxlbzo5vhz5r         0
# 19   hwk4s8wcq04yfzhins7zympsj         0
# 20   8xy1vqsyax2l55ddv4h8q15vk         0
# 21   1ki4m981itke4rodnhrj7uinw         0
# 22   2cf0dz8hreg0aqhl7qgnzpaif         0
# 23   1885tmr8tgahw6gb2slqzowg3         0
# 24   l0ko8vd8hudh5ooe85sfjey85         0
# 25   jaigkyedgpbakqbtsx35ub8vj         0
# 26   fmr8lkx2spm1zxul2qiknyg3e         0
# 27   64ope44ydukyvqnv1aupzj1b8         0
# 28   rvmgfjlhd6egglm24301in28r         0
# 29   bn09o1df8no3cvoz2ryfsgbwq         0
# ..                         ...       ...
# 970  ydx71e8jsw4hl0ay4v812bn9s         0
# 971  ztcykfn8ejmqo9wqirbv66pcf         0
# 972  h1bf0jsm9pi6ck26g2beq15bp         0
# 973  58agxya57xz33f4c8h0u5y98x         0
# 974  fmney0ybtqy9hlazj5qf3g61a         0
# 975  bjeecxp05jm3e0wblvfriw8gq         0
# 976  cfih6p5uxf99glu7b2kbouu7j         0
# 977  798qc8t0zkrusnrifumnt3tcg         0
# 978  3s4r3g7s9nqonzj48vixal4dp         0
# 979  q7105bkvmjcolbk3qnz6ndw8j         0
# 980  owl6c8jsqrfv5zzo5ut0zx7qv         0
# 981  8mj0jocfzngwzrjdtwg4vfcxg         0
# 982  1jfw2jxzhu1csorfda3zer03g         0
# 983  l8s86ma3shvy3eu9wyskaygh6         0
# 984  hv81cyth58s2cd391esen8fju         0
# 985  x1bhlm40lmk4dkxeithw0nv28         0
# 986  0ff5v9c7i6yn9672kwm22lg34         0
# 987  qg2cakoe8nzbite7g78v0dbtl         0
# 988  azfomstvjlcyihmad54zhiynj         0
# 989  gvv067tnrntn9zgykckaif4qu         0
# 990  m3bsydfu29r05bbc7aqi8hk1f         0
# 991  bnyni7cd4r1x0mht3748ql6oz         0
# 992  lka9xtrpfar41sshvh5xb1rz7         0
# 993  jjtbsdpsrs7g05nhdvcjixdy7         0
# 994  q1uow1xa8gpxx6fbip2wrrv0y         0
# 995  47y4ebgiy62x2eif4ste9po94         0
# 996  vj1d5opqic3px73b9p7coz5bg         0
# 997  olalvv956qb0a3pb9yd4d5yff         0
# 998  pyzh7f0xafqo271l59ueuy65r         0
# 999  5w3swju0y0cw7lopvxahkvefl         0
#
# [1000 rows x 2 columns]
