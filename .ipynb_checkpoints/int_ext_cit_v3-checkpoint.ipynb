# %%
# February 12st, 2020

# This script compares patent and citing in each classification system
# Second level matches specifications of Nemet and Johnson 2012
# Previous versions are not working and they are difficult to debug

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

import sys
sys.path.append('/home/rkogeyam/scripts/')
sys.path.append('scripts/')

from determinants_scripts import classes, dtypes

from classification import preprocessing

citation='data/cleanuspatentcitation.csv'

usecols=['uuid', 'patent_id', 'citation_id']
df=pd.read_csv(citation, usecols=usecols)

# %%
# %matplotlib inline

# %%
sns.set()

# %% [markdown]
# 1-Match class to patent_id and to citation_id
# 2-Create a variable coded with 1 if the classes are different, 0 if they are the same
# 3

# %%
#create classes dataset
class_df=pd.read_csv('data/wipo.csv', dtype=object, usecols=[0,1,2])
class_df=class_df.astype(str)
class_df=class_df.set_index('id')

# for class_system in class_systems:
#     classification = 'data/'+class_system+'.csv'
#     class_x=pd.read_csv(classification, dtype=object, usecols=[0,1,2])
#     class_x=class_x.astype(str)
#     class_x=class_x.set_index('id')
#     class_df=class_df.join(class_x)

# %%
class_df.dtypes
# Out:
# wipo_sector_id    object
# wipo_field_id     object
# dtype: object

# %%
df=df.astype(str)
df.set_index('patent_id', inplace=True)

# %%
df.dtypes
# Out:
# uuid           object
# citation_id    object
# dtype: object

# %%
df=df.join(class_df)

# %%
df.head()
# dimensions=list(df.columns)
# dimensions.remove('uuid')
# dimensions.remove('citation_id')
# dimensions = [sub.replace('_id', '') for sub in dimensions]
# Out:
#                               uuid citation_id wipo_sector_id wipo_field_id
# 3930271  mok3net9ll9apdxvjvf7r0mjb     2379430              4            33
# 3930271  zvlxv3wtw969uvcd9azanhlwr     2782422              4            33
# 3930272  6ddwoi89ailxhwrmj0ehi1z51     2560109              4            33
# 3930272  77qebcired4jpt5gc24ynddl1     2545289              4            33
# 3930272  af2k64rnid999g4g0hdutm75o     1549144              4            33

# %%
# df.describe()

# %%
# df.set_index('uuid', inplace=True)
# df.select_dtypes(include=[np.number]).to_csv('data/int_ext_cit_v2.csv')

# %%
df.set_index('citation_id', inplace=True)
df=df.join(class_df, lsuffix='_pat', rsuffix='_cit')
# df.describe()

# %%
df.set_index('uuid')
df['wipo_sector_ext']=np.where(df.loc[:,'wipo_sector_id_pat'] != df.loc[:,'wipo_sector_id_cit'], 1, 0)
df['wipo_field_ext']=np.where(df.loc[:,'wipo_field_id_pat'] != df.loc[:,'wipo_field_id_cit'], 1, 0)
df.loc[df.loc[:,'wipo_sector_id_pat'].isnull(), 'wipo_sector_ext'] = np.nan
df.loc[df.loc[:,'wipo_field_id_pat'].isnull(), 'wipo_field_ext'] = np.nan 
df.loc[df.loc[:,'wipo_sector_id_cit'].isnull(), 'wipo_sector_ext'] = np.nan
df.loc[df.loc[:,'wipo_field_id_cit'].isnull(), 'wipo_field_ext'] = np.nan

# %%
df.describe()
# Out:
#        wipo_sector_ext  wipo_field_ext
# count     9.145330e+07    9.145330e+07
# mean      3.787381e-01    5.141060e-01
# std       4.850727e-01    4.998010e-01
# min       0.000000e+00    0.000000e+00
# 25%       0.000000e+00    0.000000e+00
# 50%       0.000000e+00    1.000000e+00
# 75%       1.000000e+00    1.000000e+00
# max       1.000000e+00    1.000000e+00

# %%
df.sample(n=50)
# Out:
#                               uuid wipo_sector_id_pat wipo_field_id_pat  \
# 4880569  mo2o0dow30xqavv90vzdnm6ly                  0                19
# 3542150  jrh48w3mv1ev9bse1bgbgeltx                  4                35
# 4307899  g7qlaww6wau8sphq7w0n8rrab                  4                34
# 2693289  diwdz5xsnhsd6wx6e0u213wpn                  3                25
# D659270  e9747b1836edcyrptxapajb62                NaN               NaN
# 3582331  ja4nem038y6wj650cebw5f1fs                  2                09
# 5752133  nm2ecildyydz8biccezqsiuc2                  2                09
# 5680619  vfqzozr6nj805b3zus2ocd7sh                  1                06
# D322192  l4vi37rzhmb6fkl77flz7slv5                NaN               NaN
# 6619085  5whamvpxp738mlnb47td8q18i                  2                13
# 2471954  tff6metzvfhrsy1m0u5jppjae                  2                09
# 5646573  t7vm20ubm6brsmko7gzi1r7su                  1                05
# 5754939  v4wq718a1as1qcsplgn1t66li                  1                07
# D292749  h6ec604rw1ytcssbp0o4k4oux                NaN               NaN
# 4592824  dsme7quhe05fa333yil3aitej                  2                13
# 6300947  k37t0t7h8l724r9y4ydqi4sx9                  1                04
# 6287332  utpo98k08sskiy4d1dz3zwse7                  3                29
# 6461350  h7nidwqiqnyjojag4p06g2xzq                  2                13
# 5720929  gcjk9vs1t0fhpwjc8r5ybocd6                  1                08
# 5982957  9w74kydgetdbi7yflkoq4wg8i                  1                01
# 7171842  57ecnixc7nkljoejpt271mgdf                  3                32
# 5367872  bpjjehfesgkv6vkvaazwutxtv                  0                19
# 5042518  4twx8aqofbil9omi0mamzujkp                  3                25
# 4002842  umxzp9shpzro3gc0nmtjqspi6                  1                04
# 4584244  1m313yhnqkntxaxayeoxpw65m                  0                19
# 7431730  1mm0jurp90r6krl45f5j1zeu6                  2                13
# 4538236  q75us0xdqfm0t17v3v9oax99p                  1                02
# 5060899  vooa5jmhkugvuhqk9upxxpum2                  4                33
# 5282787  6wdqhf9uv9gdjwb6a7e0j9uml                  2                13
# 6711626  g2wqvozsx6o5r1l74j5y8bc5k                  1                03
# 4977938  yrvxpdfbksaa3nbqr504qhv9a                NaN               NaN
# 4363029  fi9ltzqohdy9ci0a1k1lblzeq                  1                05
# 7897022  jolx79jpn01uiwhshgsu3m1e3                  0                21
# 4265729  doavmoun9ho840xa5c32uz6cj                  0                21
# 6557054  fx9t2ms70n68veogj1y84kvc6                  1                07
# 6193550  dk5d8tv0gfdx3qimum0ab3kyl                  1                01
# 3891331  nfqvzi6y8touoyehebguwwj7o                NaN               NaN
# 6403222  wfnrnt0ls89vo166kg9cugcnl                  1                08
# 3780882  oymgfqcbgxnlrkmk6gm6szutm                  1                01
# D234617  v1r2rzsol75cnl8fo7wc6j89c                NaN               NaN
# D603356  rkru9wm9unsushb2hh5zvxob7                NaN               NaN
# 3215310  2boudrlqbhxm4i2s3piouu8iq                  2                13
# 6602245  ytwsykib1mi0du2gw4z09xxz5                  2                13
# 4149917  kxhsahdvsqap094z4ijziqi5b                  0                23
# 5953708  fgon5fd7nptjw3w3s76s2dgyi                  1                06
# 5424827  qbyib6deh1nyopbdalmk0eg7g                  2                10
# 5007082  crp50izc17psav2tflxnxnmd2                  1                06
# 5613659  0v2wl7867nmdgmwdaduf6xuzp                  4                33
# 3585984  ecg9971sb58ty3c18ok6x7cbc                  2                13
# 2787656  4uba56x0ltrkf9i2lw9ziawx7                  1                01
#
#         wipo_sector_id_cit wipo_field_id_cit  wipo_sector_ext  wipo_field_ext
# 4880569                  0                19              0.0             0.0
# 3542150                NaN               NaN              1.0             1.0
# 4307899                  4                34              0.0             0.0
# 2693289                NaN               NaN              1.0             1.0
# D659270                NaN               NaN              1.0             1.0
# 3582331                NaN               NaN              1.0             1.0
# 5752133                  2                09              0.0             0.0
# 5680619                  1                06              0.0             0.0
# D322192                NaN               NaN              1.0             1.0
# 6619085                  4                35              1.0             1.0
# 2471954                NaN               NaN              1.0             1.0
# 5646573                  1                05              0.0             0.0
# 5754939                  1                04              0.0             1.0
# D292749                NaN               NaN              1.0             1.0
# 4592824                  2                10              0.0             1.0
# 6300947                  1                06              0.0             1.0
# 6287332                  2                13              1.0             1.0
# 6461350                  2                13              0.0             0.0
# 5720929                  0                14              1.0             1.0
# 5982957                  2                10              1.0             1.0
# 7171842                  2                11              1.0             1.0
# 5367872                  3                27              1.0             1.0
# 5042518                  3                27              0.0             1.0
# 4002842                  1                03              0.0             1.0
# 4584244                  3                29              1.0             1.0
# 7431730                  2                13              0.0             0.0
# 4538236                  1                02              0.0             0.0
# 5060899                  3                32              1.0             1.0
# 5282787                  2                13              0.0             0.0
# 6711626                  1                03              0.0             0.0
# 4977938                  3                26              1.0             1.0
# 4363029                  2                10              1.0             1.0
# 7897022                  0                24              0.0             1.0
# 4265729                  1                01              1.0             1.0
# 6557054                  1                07              0.0             0.0
# 6193550                  1                01              0.0             0.0
# 3891331                NaN               NaN              1.0             1.0
# 6403222                  0                17              1.0             1.0
# 3780882                NaN               NaN              1.0             1.0
# D234617                NaN               NaN              1.0             1.0
# D603356                NaN               NaN              1.0             1.0
# 3215310                NaN               NaN              1.0             1.0
# 6602245                  2                13              0.0             0.0
# 4149917                  0                19              0.0             1.0
# 5953708                  1                07              0.0             1.0
# 5424827                  2                10              0.0             0.0
# 5007082                  1                06              0.0             0.0
# 5613659                  4                34              0.0             1.0
# 3585984                NaN               NaN              1.0             1.0
# 2787656                NaN               NaN              1.0             1.0
