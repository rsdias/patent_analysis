# %%
# February 11st, 2020
# Script to draw Originality and generality from different Classification systems

# %%
import pandas as pd
import numpy as np
# import itertools
# import seaborn as sns
# import networkx as nx
import csv
# from graphviz import Digraph
# import igraph
# import matplotlib.pyplot as plt
# import datetime


# import sys
# sys.path.append('/home/rkogeyam/scripts/')
# sys.path.append('scripts/')

# from determinants_scripts import classes, dtypes

# %%
contract='data/patent_contractawardnumber.tsv'
pat_gov='data/patent_govintorg.tsv'
gov_org='data/government_organizationt.tsv'

# df_contract=pd.read_csv(contract, chunksize=1000)
# df_pat_govt=pd.read_csv(pat_gov, chunksize=1000)
# df_gov_org=pd.read_csv(gov_org, chunksize=1000)


# names=['index', 'id', 'cit_received']
# usecols=['id', 'cit_received']
# dtype={'main_group':'int64', 'subgroup':'int64'}
# cols=['patent_id','citation_id', 'cit_delay']

# usecols=['patent_id', 'citation_id']|

# df_pat=pd.read_csv(pat, index_col='id', chunksize=10000)

# file='data/patcitonly.csv'
file='data/eigen.csv'
df=pd.read_csv(file, chunksize=100, engine='c', lineterminator='\n')

# df=pd.read_csv(file, chunksize=1000)


# usecols=['patent_id', 'citation_id']
# df_cit=pd.read_csv(file, usecols=usecols, index_col='patent_id', chunksize=1000)

# df_asg=pd.read_csv(asg, sep='\t', chunksize=10000)

# df_cit=pd.read_csv(cit, usecols=usecols, chunksize=10000)
# 
# df=pd.read_csv(src, dtype=dtypes, usecols=usecols, parse_dates=['date'], index_col='id', chunksize=10000)
# df = pd.read_csv(src, chunksize=1000, usecols=usecols, dtypes=dtypes, parse_dates=['date'])

# df = pd.read_csv(src, chunksize=1000,  parse_dates=['date'], error_bad_lines=False)
# df = pd.read_csv(src, usecols=usecols, names=names, chunksize=1000, dtype=dtype, index_col='id')
# df=pd.read_csv(src, usecols=[0, 1, 3], dtype={0:object}, index_col=0, chunksize=1000)

# %%
# %matplotlib inline

# %%
df.get_chunk()
# Out:
#          id  eigen      pagerank      katz
# 0   5333265    0.0  1.940869e-06  0.000615
# 1   5333264    0.0  5.959012e-08  0.000286
# 2   5333267    0.0  6.419989e-08  0.000294
# 3   5333266    0.0  8.461237e-06  0.003505
# 4   5333261    0.0  8.828938e-08  0.000325
# 5   5333260    0.0  1.134963e-07  0.000320
# 6   5333263    0.0  5.918580e-08  0.000291
# 7   5333262    0.0  3.573957e-07  0.000325
# 8   8189827    0.0  5.671030e-08  0.000286
# 9   5333269    0.0  5.234322e-07  0.000431
# 10  5333268    0.0  3.330165e-07  0.000393
# 11  8844361    0.0  7.134711e-08  0.000289
# 12  2008919    0.0  1.481009e-07  0.000319
# 13  7327622    0.0  5.673386e-08  0.000283
# 14  2008915    0.0  4.597114e-08  0.000284
# 15  2008914    0.0  4.951125e-08  0.000286
# 16  2008911    0.0  4.557316e-08  0.000283
# 17  7327623    0.0  5.499953e-08  0.000286
# 18  8844364    0.0  4.420821e-08  0.000280
# 19  3349170    0.0  1.597717e-07  0.000289
# 20   287143    0.0  4.795587e-08  0.000283
# 21  7447649    0.0  1.401882e-07  0.000301
# 22  3784606    0.0  1.273860e-07  0.000293
# 23  3784605    0.0  2.222276e-07  0.000310
# 24  4630643    0.0  5.816306e-08  0.000290
# 25  4134638    0.0  1.107829e-07  0.000298
# 26  4134639    0.0  3.554803e-07  0.000303
# 27  3209313    0.0  4.872652e-08  0.000284
# 28  3784600    0.0  4.241242e-07  0.000312
# 29  4134634    0.0  1.264115e-07  0.000319
# ..      ...    ...           ...       ...
# 70  7386051    0.0  4.420821e-08  0.000280
# 71  7447644    0.0  5.119986e-08  0.000295
# 72  5736839    0.0  5.382176e-08  0.000289
# 73  D756853    0.0  4.420821e-08  0.000280
# 74  4522415    0.0  9.167683e-08  0.000310
# 75      NaN    0.0  1.606280e-06  0.000359
# 76  8911704    0.0  4.420821e-08  0.000280
# 77  8911707    0.0  4.733962e-08  0.000286
# 78  8911706    0.0  4.420821e-08  0.000280
# 79  8911701    0.0  4.420821e-08  0.000280
# 80  8911700    0.0  4.420821e-08  0.000280
# 81  8911703    0.0  4.727264e-08  0.000286
# 82  8911702    0.0  4.420821e-08  0.000280
# 83  1341795    0.0  6.117990e-08  0.000284
# 84  8911709    0.0  4.420821e-08  0.000280
# 85  8911708    0.0  5.023015e-08  0.000286
# 86  3519820    0.0  1.053215e-07  0.000288
# 87  5564108    0.0  2.247758e-07  0.000673
# 88  5564109    0.0  6.907728e-07  0.000614
# 89  5564102    0.0  1.246455e-07  0.000310
# 90  5564103    0.0  6.619072e-08  0.000283
# 91  5564100    0.0  9.432523e-08  0.000302
# 92  5564101    0.0  1.992085e-07  0.000513
# 93  5564106    0.0  2.008278e-07  0.000373
# 94  5564107    0.0  5.765511e-08  0.000292
# 95  5564104    0.0  1.186013e-07  0.000330
# 96  5564105    0.0  9.885272e-08  0.000341
# 97  9737270    0.0  4.420821e-08  0.000280
# 98  9737271    0.0  4.420821e-08  0.000280
# 99  3519827    0.0  1.012739e-07  0.000290
#
# [100 rows x 4 columns]

# %%
df=df.get_chunk()

# %%
df.eigen.hist()

# %%
df.pagerank.hist()

# %%
df.katz.hist()

# %%
m  m
# Out:
#   File "<ipython-input-10-458cf5000cfa>", line 1
#     m  m
#        ^
# SyntaxError: invalid syntax
