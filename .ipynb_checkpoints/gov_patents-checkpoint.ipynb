# %%
# February 14st, 2020
# Government patents

# %%
import pandas as pd
import numpy as np
# import itertools
import seaborn as sns
# import networkx as nx
# import csv
# from graphviz import Digraph
# import igraph
import matplotlib.pyplot as plt
# import datetime


# import sys
# sys.path.append('/home/rkogeyam/scripts/')
# sys.path.append('scripts/')

# from determinants_scripts import classes, dtypes

# %%
contract='data/patent_contractawardnumber.tsv'
pat_gov='data/patent_govintorg.tsv'
gov_org='data/government_organization.tsv'

# df_contract=pd.read_csv(contract, sep='\t', chunksize=1000)
# df_pat_govt=pd.read_csv(pat_gov,  sep='\t', chunksize=1000)
# df_gov_org=pd.read_csv(gov_org,  sep='\t', chunksize=1000)
df_contract=pd.read_csv(contract, sep='\t')
df_pat_govt=pd.read_csv(pat_gov,  sep='\t')
df_gov_org=pd.read_csv(gov_org,  sep='\t')

# %%
patent='data/cleanpatent.csv'
usecols=['id', 'date', 'kind']
# df_pat=pd.read_csv(patent, chunksize=100000, usecols=usecols)
df_pat=pd.read_csv(patent, usecols=usecols, parse_dates=['date'] )
# Out:
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# %matplotlib inline
sns.set()
# %config InlineBackend.figure_format = 'retina'

# %%
df=df_pat_govt.groupby('patent_id').count()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143415 entries, 10000026 to RE47622
# Data columns (total 1 columns):
# organization_id    143415 non-null int64
# dtypes: int64(1)
# memory usage: 2.2+ MB

# %%
df_pat.describe()
# Out:
#              id                 date
# count   6488256              6488256
# unique  6488256                 2218
# top     D579293  2017-04-18 00:00:00
# freq          1                 7602
# first       NaN  1976-01-06 00:00:00
# last        NaN  2017-12-26 00:00:00

# %%
df=df.merge(df_pat, left_index=True, right_on='id', how='inner')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6933 entries, 5636173 to 6488196
# Data columns (total 3 columns):
# organization_id    6933 non-null int64
# id                 6933 non-null object
# date               6933 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 216.7+ KB

# %%
df_pat.groupby(pd.Grouper(key='date', freq="A")).count()
# Out:
#                 id
# date
# 1976-12-31   70941
# 1977-12-31   69820
# 1978-12-31   70586
# 1979-12-31   52484
# 1980-12-31   66212
# 1981-12-31   71112
# 1982-12-31   63292
# 1983-12-31   62019
# 1984-12-31   72689
# 1985-12-31   77276
# 1986-12-31   77050
# 1987-12-31   89591
# 1988-12-31   84449
# 1989-12-31  102719
# 1990-12-31   99275
# 1991-12-31  106891
# 1992-12-31  107540
# 1993-12-31  109933
# 1994-12-31  113723
# 1995-12-31  113954
# 1996-12-31  121811
# 1997-12-31  124181
# 1998-12-31  163265
# 1999-12-31  169252
# 2000-12-31  176192
# 2001-12-31  184172
# 2002-12-31  184494
# 2003-12-31  187104
# 2004-12-31  181413
# 2005-12-31  157829
# 2006-12-31  196489
# 2007-12-31  182978
# 2008-12-31  185260
# 2009-12-31  192052
# 2010-12-31  244599
# 2011-12-31  248101
# 2012-12-31  263638
# 2013-12-31  302628
# 2014-12-31  327014
# 2015-12-31  326969
# 2016-12-31  334674
# 2017-12-31  352585

# %%
fig, ax=plt.subplots(figsize=(12,8))
df_pat.groupby(pd.Grouper(key='date', freq="A")).count().plot(ax=ax)
ax.set_title('Total Patent Grant', fontsize=20)
plt.legend('')
# Out:
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6933 entries, 5636173 to 6488196
# Data columns (total 3 columns):
# organization_id    6933 non-null int64
# id                 6933 non-null object
# date               6933 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 216.7+ KB

# %%
df.groupby(pd.Grouper(key='date', freq="A")).count()
# Out:
#             organization_id    id
# date
# 1976-12-31                3     3
# 1977-12-31                1     1
# 1978-12-31                2     2
# 1979-12-31                5     5
# 1980-12-31                2     2
# 1981-12-31                3     3
# 1982-12-31                5     5
# 1983-12-31                5     5
# 1984-12-31                3     3
# 1985-12-31                1     1
# 1986-12-31               80    80
# 1987-12-31              105   105
# 1988-12-31               85    85
# 1989-12-31               82    82
# 1990-12-31               79    79
# 1991-12-31               74    74
# 1992-12-31               49    49
# 1993-12-31               64    64
# 1994-12-31               46    46
# 1995-12-31               39    39
# 1996-12-31               34    34
# 1997-12-31               18    18
# 1998-12-31               12    12
# 1999-12-31               12    12
# 2000-12-31               21    21
# 2001-12-31               24    24
# 2002-12-31               20    20
# 2003-12-31               13    13
# 2004-12-31               17    17
# 2005-12-31               15    15
# 2006-12-31               26    26
# 2007-12-31               26    26
# 2008-12-31               22    22
# 2009-12-31               20    20
# 2010-12-31               51    51
# 2011-12-31               39    39
# 2012-12-31               29    29
# 2013-12-31               34    34
# 2014-12-31               30    30
# 2015-12-31               19    19
# 2016-12-31               26    26
# 2017-12-31             5692  5692

# %%
df[df['date'].dt.year==2017]
# Out:
#          organization_id       id       date
# 5636173                1  9609238 2017-03-28
# 5636688                1  9609756 2017-03-28
# 5636723                3  9609791 2017-03-28
# 5636793                1  9609861 2017-04-04
# 5636948                2  9610016 2017-04-04
# 5636993                1  9610061 2017-04-04
# 5637063                1  9610131 2017-04-04
# 5637182                2  9610250 2017-04-04
# 5637198                1  9610266 2017-04-04
# 5637250                1  9610319 2017-04-04
# 5637251                1  9610320 2017-04-04
# 5637253                1  9610322 2017-04-04
# 5637259                1  9610328 2017-04-04
# 5637263                1  9610332 2017-04-04
# 5637269                1  9610338 2017-04-04
# 5637277                1  9610346 2017-04-04
# 5637286                1  9610355 2017-04-04
# 5637289                1  9610358 2017-04-04
# 5637290                1  9610359 2017-04-04
# 5637294                1  9610363 2017-04-04
# 5637295                1  9610364 2017-04-04
# 5637302                4  9610371 2017-04-04
# 5637461                2  9610531 2017-04-04
# 5637468                2  9610538 2017-04-04
# 5637474                3  9610544 2017-04-04
# 5637477                1  9610547 2017-04-04
# 5637492                1  9610562 2017-04-04
# 5637510                2  9610580 2017-04-04
# 5637519                1  9610589 2017-04-04
# 5637538                1  9610608 2017-04-04
# ...                  ...      ...        ...
# 6327176                1  PP27618 2017-01-24
# 6327201                1  PP27643 2017-02-07
# 6327340                1  PP27782 2017-03-14
# 6327439                1  PP27881 2017-04-11
# 6327758                1  PP28200 2017-07-18
# 6327774                1  PP28216 2017-07-25
# 6408102                1  PP28372 2017-09-12
# 6408138                1  PP28408 2017-09-19
# 6408139                1  PP28409 2017-09-19
# 6408179                1  PP28449 2017-09-26
# 6408182                1  PP28452 2017-09-26
# 6408197                1  PP28467 2017-10-03
# 6487905                1  PP28567 2017-10-24
# 6487919                1  PP28581 2017-10-31
# 6487961                1  PP28623 2017-11-14
# 6487962                1  PP28624 2017-11-14
# 6488003                1  PP28665 2017-11-21
# 6488127                1  PP28789 2017-12-26
# 6488144                1  PP28806 2017-12-26
# 6351258                1  RE46290 2017-01-31
# 6351290                2  RE46322 2017-02-28
# 6351319                1  RE46351 2017-03-28
# 6351340                1  RE46372 2017-04-25
# 6351380                1  RE46412 2017-05-23
# 6351391                1  RE46423 2017-06-06
# 6351447                1  RE46479 2017-07-18
# 6351461                2  RE46493 2017-08-01
# 6408264                1  RE46545 2017-09-12
# 6488186                1  RE46584 2017-10-24
# 6488196                1  RE46594 2017-10-31
#
# [5692 rows x 3 columns]

# %%
df.describe()

# %%
df.head()
