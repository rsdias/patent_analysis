# %%
import pandas as pd
import gzip

file_classes=gzip.open('data/classes.csv.gz', 'r')
df_classes=pd.read_csv(file_classes)
df_classes.rename(columns={'id': 'class_id'}, inplace=True)

# %%
df_classes
# Out:
#               system class_id  \
# 0      wipo_field_id       01
# 1      wipo_field_id       02
# 2      wipo_field_id       03
# 3      wipo_field_id       04
# 4      wipo_field_id       05
# 5      wipo_field_id       06
# 6      wipo_field_id       07
# 7      wipo_field_id       08
# 8      wipo_field_id       09
# 9      wipo_field_id       10
# 10     wipo_field_id       11
# 11     wipo_field_id       12
# 12     wipo_field_id       13
# 13     wipo_field_id       14
# 14     wipo_field_id       15
# 15     wipo_field_id       16
# 16     wipo_field_id       17
# 17     wipo_field_id       18
# 18     wipo_field_id       19
# 19     wipo_field_id       20
# 20     wipo_field_id       21
# 21     wipo_field_id       22
# 22     wipo_field_id       23
# 23     wipo_field_id       24
# 24     wipo_field_id       25
# 25     wipo_field_id       26
# 26     wipo_field_id       27
# 27     wipo_field_id       28
# 28     wipo_field_id       29
# 29     wipo_field_id       30
# 30     wipo_field_id       31
# 31     wipo_field_id       32
# 32     wipo_field_id       33
# 33     wipo_field_id       34
# 34     wipo_field_id       35
# 35     wipo_field_id       36
# 36  nber_category_id        1
# 37  nber_category_id        2
# 38  nber_category_id        3
# 39  nber_category_id        4
# 40  nber_category_id        5
# 41  nber_category_id        6
# 42      ipcr_section        A
# 43      ipcr_section        B
# 44      ipcr_section        C
# 45      ipcr_section        D
# 46      ipcr_section        E
# 47      ipcr_section        F
# 48      ipcr_section        G
# 49      ipcr_section        H
# 50    cpc_section_id        A
# 51    cpc_section_id        B
# 52    cpc_section_id        C
# 53    cpc_section_id        D
# 54    cpc_section_id        E
# 55    cpc_section_id        F
# 56    cpc_section_id        G
# 57    cpc_section_id        H
# 58    cpc_section_id        Y
#
#                                          sector_title  \
# 0                                      Electrical Eng
# 1                                      Electrical Eng
# 2                                      Electrical Eng
# 3                                      Electrical Eng
# 4                                      Electrical Eng
# 5                                      Electrical Eng
# 6                                      Electrical Eng
# 7                                      Electrical Eng
# 8                                         Instruments
# 9                                         Instruments
# 10                                        Instruments
# 11                                        Instruments
# 12                                        Instruments
# 13                                          Chemistry
# 14                                          Chemistry
# 15                                          Chemistry
# 16                                          Chemistry
# 17                                          Chemistry
# 18                                          Chemistry
# 19                                          Chemistry
# 20                                          Chemistry
# 21                                          Chemistry
# 22                                          Chemistry
# 23                                          Chemistry
# 24                                     Mechanical Eng
# 25                                     Mechanical Eng
# 26                                     Mechanical Eng
# 27                                     Mechanical Eng
# 28                                     Mechanical Eng
# 29                                     Mechanical Eng
# 30                                     Mechanical Eng
# 31                                     Mechanical Eng
# 32                                       Other fields
# 33                                       Other fields
# 34                                       Other fields
# 35                                              Plant
# 36                                           Chemical
# 37                                            Cmp&Cmm
# 38                                           Drgs&Med
# 39                                               Elec
# 40                                               Mech
# 41                                             Others
# 42                                 Human Necessitites
# 43                Performing Operations; Transporting
# 44                              Chemistry; Metallurgy
# 45                                    Textiles; Paper
# 46                                Fixed Constructions
# 47  Mechanical Eng; Lighting; Heating; Weapons; Bl...
# 48                                            Physics
# 49                                        Electricity
# 50                                 Human Necessitites
# 51                Performing Operations; Transporting
# 52                              Chemistry; Metallurgy
# 53                                    Textiles; Paper
# 54                                Fixed Constructions
# 55  Mechanical Eng; Lighting; Heating; Weapons;Bla...
# 56                                            Physics
# 57                                        Electricity
# 58  General Tagging of New Technological Developments
#
#                                 field_title
# 0   Electrical machinery, apparatus, energy
# 1                   Audio-visual technology
# 2                        Telecommunications
# 3                     Digital communication
# 4             Basic communication processes
# 5                       Computer technology
# 6                 IT methods for management
# 7                            Semiconductors
# 8                                    Optics
# 9                               Measurement
# 10         Analysis of biological materials
# 11                                  Control
# 12                       Medical technology
# 13                   Organic fine chemistry
# 14                            Biotechnology
# 15                          Pharmaceuticals
# 16       Macromolecular chemistry, polymers
# 17                           Food chemistry
# 18                Basic materials chemistry
# 19                    Materials, metallurgy
# 20              Surface technology, coating
# 21     Micro-structural and nano-technology
# 22                             Chemical Eng
# 23                 Environmental technology
# 24                                 Handling
# 25                            Machine tools
# 26                 Engines, pumps, turbines
# 27               Textile and paper machines
# 28                   Other special machines
# 29          Thermal processes and apparatus
# 30                      Mechanical elements
# 31                                Transport
# 32                         Furniture, games
# 33                     Other consumer goods
# 34                                Civil Eng
# 35                                    Plant
# 36                                      NaN
# 37                                      NaN
# 38                                      NaN
# 39                                      NaN
# 40                                      NaN
# 41                                      NaN
# 42                                      NaN
# 43                                      NaN
# 44                                      NaN
# 45                                      NaN
# 46                                      NaN
# 47                                      NaN
# 48                                      NaN
# 49                                      NaN
# 50                                      NaN
# 51                                      NaN
# 52                                      NaN
# 53                                      NaN
# 54                                      NaN
# 55                                      NaN
# 56                                      NaN
# 57                                      NaN
# 58                                      NaN

# %%
class_system='wipo_field_id'
df_classes[df_classes['system']==class_system]
# Out:
#            system class_id    sector_title  \
# 0   wipo_field_id       01  Electrical Eng
# 1   wipo_field_id       02  Electrical Eng
# 2   wipo_field_id       03  Electrical Eng
# 3   wipo_field_id       04  Electrical Eng
# 4   wipo_field_id       05  Electrical Eng
# 5   wipo_field_id       06  Electrical Eng
# 6   wipo_field_id       07  Electrical Eng
# 7   wipo_field_id       08  Electrical Eng
# 8   wipo_field_id       09     Instruments
# 9   wipo_field_id       10     Instruments
# 10  wipo_field_id       11     Instruments
# 11  wipo_field_id       12     Instruments
# 12  wipo_field_id       13     Instruments
# 13  wipo_field_id       14       Chemistry
# 14  wipo_field_id       15       Chemistry
# 15  wipo_field_id       16       Chemistry
# 16  wipo_field_id       17       Chemistry
# 17  wipo_field_id       18       Chemistry
# 18  wipo_field_id       19       Chemistry
# 19  wipo_field_id       20       Chemistry
# 20  wipo_field_id       21       Chemistry
# 21  wipo_field_id       22       Chemistry
# 22  wipo_field_id       23       Chemistry
# 23  wipo_field_id       24       Chemistry
# 24  wipo_field_id       25  Mechanical Eng
# 25  wipo_field_id       26  Mechanical Eng
# 26  wipo_field_id       27  Mechanical Eng
# 27  wipo_field_id       28  Mechanical Eng
# 28  wipo_field_id       29  Mechanical Eng
# 29  wipo_field_id       30  Mechanical Eng
# 30  wipo_field_id       31  Mechanical Eng
# 31  wipo_field_id       32  Mechanical Eng
# 32  wipo_field_id       33    Other fields
# 33  wipo_field_id       34    Other fields
# 34  wipo_field_id       35    Other fields
# 35  wipo_field_id       36           Plant
#
#                                 field_title
# 0   Electrical machinery, apparatus, energy
# 1                   Audio-visual technology
# 2                        Telecommunications
# 3                     Digital communication
# 4             Basic communication processes
# 5                       Computer technology
# 6                 IT methods for management
# 7                            Semiconductors
# 8                                    Optics
# 9                               Measurement
# 10         Analysis of biological materials
# 11                                  Control
# 12                       Medical technology
# 13                   Organic fine chemistry
# 14                            Biotechnology
# 15                          Pharmaceuticals
# 16       Macromolecular chemistry, polymers
# 17                           Food chemistry
# 18                Basic materials chemistry
# 19                    Materials, metallurgy
# 20              Surface technology, coating
# 21     Micro-structural and nano-technology
# 22                             Chemical Eng
# 23                 Environmental technology
# 24                                 Handling
# 25                            Machine tools
# 26                 Engines, pumps, turbines
# 27               Textile and paper machines
# 28                   Other special machines
# 29          Thermal processes and apparatus
# 30                      Mechanical elements
# 31                                Transport
# 32                         Furniture, games
# 33                     Other consumer goods
# 34                                Civil Eng
# 35                                    Plant

# %%
df_classes['class_id']=df_classes['class_id'].apply('{:0>2}'.format)
