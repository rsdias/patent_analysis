# %%
import pandas as pd

# %%
df=pd.read_csv('df_w_pat_cit.csv')
df['date']=pd.to_datetime(df.date, errors='coerce')
# Out:
# /home/applications/anaconda3/4.2.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df[df['date'].isnull()]
# Out:
#                                                         id number country  \
# 2640192  eception units. Sequentially, during data tran...    NaN     NaN
# 2640193  eception, whether or not a transmission signal...    NaN     NaN
# 2640194  eception unit receiving said signal is used fo...    NaN     NaN
# 2640195  eception via optical communications with an ex...     B1       7
# 3724933  \n end-of-message indicator and uses the vario...     B1      18
#
#         date abstract title  num_claims filename  citation_id  \
# 2640192  NaT      NaN   NaN         NaN      NaN          0.0
# 2640193  NaT      NaN   NaN         NaN      NaN          0.0
# 2640194  NaT      NaN   NaN         NaN      NaN          0.0
# 2640195  NaT      NaN   NaN         NaN      NaN          0.0
# 3724933  NaT      NaN   NaN         NaN      NaN          0.0
#
#          type_Device provided with an optical communications function and optical communication system  \
# ...
