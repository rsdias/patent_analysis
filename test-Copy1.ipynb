# %%
# February 11st, 2020
# Script to draw Originality and generality from different Classification systems

# %%
import pandas as pd
import numpy as np
# import itertools
# import seaborn as sns
# import networkx as nx
import csv
# from graphviz import Digraph
# import igraph
# import matplotlib.pyplot as plt
# import datetime


# import sys
# sys.path.append('/home/rkogeyam/scripts/')
# sys.path.append('scripts/')

# from determinants_scripts import classes, dtypes

# %%
file='data/eigen.csv'
#df=pd.read_csv(file, chunksize=100, engine='c', lineterminator='\n')

df=pd.read_csv(file, chunksize=1000)


# usecols=['patent_id', 'citation_id']
# df_cit=pd.read_csv(file, usecols=usecols, index_col='patent_id', chunksize=1000)

# df_asg=pd.read_csv(asg, sep='\t', chunksize=10000)

# df_cit=pd.read_csv(cit, usecols=usecols, chunksize=10000)
# 
# df=pd.read_csv(src, dtype=dtypes, usecols=usecols, parse_dates=['date'], index_col='id', chunksize=10000)
# df = pd.read_csv(src, chunksize=1000, usecols=usecols, dtypes=dtypes, parse_dates=['date'])

# df = pd.read_csv(src, chunksize=1000,  parse_dates=['date'], error_bad_lines=False)
# df = pd.read_csv(src, usecols=usecols, names=names, chunksize=1000, dtype=dtype, index_col='id')
# df=pd.read_csv(src, usecols=[0, 1, 3], dtype={0:object}, index_col=0, chunksize=1000)

# %%
# %matplotlib inline

# %%
df.get_chunk()
# Out:
#           id  eigen      pagerank      katz
# 0    5333265    0.0  1.940866e-06  0.000615
# 1    5333264    0.0  5.959024e-08  0.000286
# 2    5333267    0.0  6.420002e-08  0.000294
# 3    5333266    0.0  8.461707e-06  0.003505
# 4    5333261    0.0  8.828956e-08  0.000325
# 5    5333260    0.0  1.134965e-07  0.000320
# 6    5333263    0.0  5.918593e-08  0.000291
# 7    5333262    0.0  3.573964e-07  0.000325
# 8    8189827    0.0  5.671041e-08  0.000286
# 9    5333269    0.0  5.234296e-07  0.000431
# 10   5333268    0.0  3.330032e-07  0.000393
# 11   8844361    0.0  7.134726e-08  0.000289
# 12   2008919    0.0  1.481011e-07  0.000319
# 13   7327622    0.0  5.673397e-08  0.000283
# 14   2008915    0.0  4.597124e-08  0.000284
# 15   2008914    0.0  4.951136e-08  0.000286
# 16   2008911    0.0  4.557326e-08  0.000283
# 17   7327623    0.0  5.499965e-08  0.000286
# 18   8844364    0.0  4.420830e-08  0.000280
# 19   3349170    0.0  1.597718e-07  0.000289
# 20    287143    0.0  4.795596e-08  0.000283
# 21   7447649    0.0  1.401885e-07  0.000301
# 22   3784606    0.0  1.273863e-07  0.000293
# 23   3784605    0.0  2.222280e-07  0.000310
# 24   4630643    0.0  5.816318e-08  0.000290
# 25   4134638    0.0  1.107832e-07  0.000298
# 26   4134639    0.0  3.554797e-07  0.000303
# 27   3209313    0.0  4.872662e-08  0.000284
# 28   3784600    0.0  4.241250e-07  0.000312
# 29   4134634    0.0  1.264118e-07  0.000319
# ..       ...    ...           ...       ...
# 970  1032527    0.0  6.766347e-08  0.000287
# 971  1795054    0.0  5.263527e-08  0.000286
# 972  4022961    0.0  1.020312e-07  0.000284
# 973  4439575    0.0  9.610460e-08  0.000300
# 974  4308228    0.0  5.475724e-08  0.000295
# 975  4308229    0.0  2.196392e-07  0.000339
# 976  5094128    0.0  1.712362e-07  0.000302
# 977  4308222    0.0  1.041033e-07  0.000314
# 978  4308223    0.0  2.404395e-07  0.000382
# 979  4308220    0.0  9.323398e-08  0.000304
# 980  4308221    0.0  1.308442e-07  0.000358
# 981  4308226    0.0  1.610196e-07  0.000324
# 982  4308227    0.0  9.992089e-08  0.000295
# 983  4308224    0.0  1.398694e-07  0.000324
# 984  4308225    0.0  1.092149e-07  0.000310
# 985  7351313    0.0  4.802400e-08  0.000292
# 986  4140335    0.0  4.741849e-08  0.000287
# 987  5466325    0.0  5.505532e-07  0.000405
# 988  D464633    0.0  1.069263e-07  0.000333
# 989  4022967    0.0  2.953285e-07  0.000312
# 990  7351311    0.0  5.075581e-08  0.000286
# 991  9113588    0.0  4.420830e-08  0.000280
# 992  9113589    0.0  4.476289e-08  0.000294
# 993  D464631    0.0  5.838025e-08  0.000306
# 994  5094129    0.0  1.491699e-07  0.000301
# 995  3453853    0.0  4.698941e-08  0.000284
# 996  9113580    0.0  4.420830e-08  0.000280
# 997  9113581    0.0  4.977527e-08  0.000286
# 998  9113582    0.0  4.420830e-08  0.000280
# 999  9113583    0.0  4.420830e-08  0.000280
#
# [1000 rows x 4 columns]
