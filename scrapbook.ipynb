# %%
import pandas as pd
import gzip

file_classes=gzip.open('data/classes.csv.gz', 'r')
df_classes=pd.read_csv(file_classes)
df_classes.rename(columns={'id': 'class_id'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-be6627c81153> in <module>()
#       2 import gzip
#       3
# ----> 4 file_classes=gzip.open('data/classes.csv.gz', 'r')
#       5 df_classes=pd.read_csv(file_classes)
#       6 df_classes.rename(columns={'id': 'class_id'}, inplace=True)
#
# /home/applications/anaconda3/4.2.0/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      51     gz_mode = mode.replace("t", "")
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      55         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# /home/applications/anaconda3/4.2.0/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
# ...

# %%
int(2000//10*10)
# Out:
# 2000

# %%
classification = 'data/dataset.csv.gz'
file_class=gzip.open(classification, 'rt')
class_df=pd.read_csv(file_class, dtype=object, nrows=10000)

# %%
class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
# id                    10000 non-null object
# type                  9145 non-null object
# number                9145 non-null object
# country               9145 non-null object
# date                  9145 non-null object
# abstract              9145 non-null object
# title                 9145 non-null object
# kind                  9145 non-null object
# num_claims            9145 non-null object
# filename              9145 non-null object
# withdrawn             29 non-null object
# cit_received          10000 non-null object
# cit_made              0 non-null object
# cit_received_delay    2624 non-null object
# cit_made_delay        7916 non-null object
# originality           7859 non-null object
# generality            781 non-null object
# wipo_sector_id        9112 non-null object
# wipo_field_id         9112 non-null object
# ...

# %%
class_system='wipo_field_id'
df_classes[df_classes['system']==class_system]
# Out:
#            system class_id    sector_title  \
# 0   wipo_field_id       01  Electrical Eng
# 1   wipo_field_id       02  Electrical Eng
# 2   wipo_field_id       03  Electrical Eng
# 3   wipo_field_id       04  Electrical Eng
# 4   wipo_field_id       05  Electrical Eng
# 5   wipo_field_id       06  Electrical Eng
# 6   wipo_field_id       07  Electrical Eng
# 7   wipo_field_id       08  Electrical Eng
# 8   wipo_field_id       09     Instruments
# 9   wipo_field_id       10     Instruments
# 10  wipo_field_id       11     Instruments
# 11  wipo_field_id       12     Instruments
# 12  wipo_field_id       13     Instruments
# 13  wipo_field_id       14       Chemistry
# 14  wipo_field_id       15       Chemistry
# 15  wipo_field_id       16       Chemistry
# 16  wipo_field_id       17       Chemistry
# 17  wipo_field_id       18       Chemistry
# 18  wipo_field_id       19       Chemistry
# 19  wipo_field_id       20       Chemistry
# 20  wipo_field_id       21       Chemistry
# ...

# %%
df_classes['class_id']=df_classes['class_id'].apply('{:0>2}'.format)
